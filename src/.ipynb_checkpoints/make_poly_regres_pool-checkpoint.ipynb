# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def quad(x,a0,a1,a2):
    """functional form we are fitting"""
    return a2*x*x + a1*x + a0

# %%
def cubic(x,a0,a1,a2,a3):
    """functional form we are fitting"""
    return a3*x*x*x + a2*x*x + a1*x + a0

# %%
def generate_data():
    """
    generates a data set and calculates 
    parameters for linear regression
    """
    N = np.random.randint(16,31)
    a3 = float(np.random.randint(-1,1) )
    a2 = float(np.random.randint(-5,5) )
    a1 = float(np.random.randint(-5,5) )
    a0 = float(np.random.randint(-5,5) )
    x = np.linspace(-10,10,N)
    noise_mag = np.random.randint(1,2) + 0.1
    y_noise = np.random.normal(0,noise_mag,N) # normally distributed noise

    if (np.random.rand() < 1.0):
        y = quad(x,a0,a1,a2) + y_noise
        z = np.polyfit(x, y, 2)
        p = np.poly1d(z)
    else:
        y = cubic(x,a0,a1,a2,a3) + y_noise
        z, residuals, rank, singular_values, rcond = np.polyfit(x, y, 3, full='True')
        p = np.poly1d(z)
        
    #slope,intercept, r_value, p_value, std_err = stats.linregress(x,y)
    plt.plot(x,y,linestyle="", marker='x');
    plt.plot(x,p(x),linestyle="-", marker='');
    return x, y, z

# %%
generate_data()
# Out:
# (array([-10.        ,  -9.23076923,  -8.46153846,  -7.69230769,
#          -6.92307692,  -6.15384615,  -5.38461538,  -4.61538462,
#          -3.84615385,  -3.07692308,  -2.30769231,  -1.53846154,
#          -0.76923077,   0.        ,   0.76923077,   1.53846154,
#           2.30769231,   3.07692308,   3.84615385,   4.61538462,
#           5.38461538,   6.15384615,   6.92307692,   7.69230769,
#           8.46153846,   9.23076923,  10.        ]),
#  array([ 40.14658591,  36.58866831,  32.75377287,  31.06290187,
#          26.95186676,  24.99771064,  21.69896481,  16.84092202,
#          16.77350339,  13.06839918,   9.80618266,   8.30522468,
#           2.17262067,   0.83609174,  -1.41288282,  -5.97117077,
#          -9.92274843, -11.72287064, -16.35844462, -18.06448285,
#         -20.97586989, -25.29590293, -27.8841844 , -30.31194116,
#         -32.64550301, -35.3314485 , -42.0555893 ]),
#  array([-0.00771408, -3.98808706,  0.42692949]))

# %%
def print_data(x,y):
    """
    prepare data for insertion into Blackboard test - i.e. html
    """
    my_data = "\(x_i\) \t \t \(y_i\)<br>"
    for xi, yi in zip(x,y):
        my_data = my_data + str('{:f}'.format(xi)) + "\t" + str('{:f}'.format(yi)) + "<br>"

    return my_data

# %% [markdown]
# ### Useful sites
#
# https://eli.thegreenplace.net/2012/03/15/processing-xml-in-python-with-elementtree
# https://msdn.microsoft.com/en-us/library/ms256086(v=vs.110).aspx
# https://docs.python.org/2/library/xml.etree.elementtree.html

# %%
tree = ET.ElementTree(file='template/res00001.dat')
root = tree.getroot()

# %%
#for elem in tree.iter(tag='item'):
#    print(elem.tag, elem.attrib)

# %%
# Nodes that have an 'item' child
for item in root.findall(".//*[item]"):
    section = item
    
# make a copy of original question(s)
template = []
for elem in tree.iter(tag='item'):
    template.append(copy.deepcopy(elem))
    section.remove(elem) # delete template

# %%
number_of_questions = 30
for i in range(number_of_questions):
    question = copy.deepcopy(template)
    x, y, z = generate_data()
    my_data = print_data(x,y)
    my_text_cube = """
    <p>Assume that the following data is of the form.<br>
    \( y_i = a_0 + a_1 x + a_2 x^2 + a_3 x^3 + e_i\)<br>
    What is the coefficient of \(x^3\) ( \(a_3\) ) in your fit to the data?</p><br><p>
    """
    my_text_quad = """
    <p>Assume that the following data is of the form.<br>
    \( y_i = a_0 + a_1 x + a_2 x^2 + + e_i\)<br>
    What is the coefficient of \(x^2\) ( \(a_2\) ) in your fit to the data?</p><br><p>
    """

    my_script = '<p><script type="text/javascript" src="https://cdn.mathjax.org/mathjax/latest/MathJax.js?config=TeX-MML-AM_CHTML"></script></p>'
    question_text = my_text_quad + my_data + "</p>" + my_script
    question[0][1][0][0][0][0][0][0].text = question_text
    question[0][2][1][0][0].text = str('{:f}'.format(z[0]-0.001))
    question[0][2][1][0][1].text = str('{:f}'.format(z[0]+0.001))
    question[0][2][1][0][2].text = str('{:f}'.format(z[0]))
    section.append(question[0])

# %%
#for elem in tree.iter(tag='item'):
#    print(elem.tag, elem.attrib)

# %%
# finally output
tree.write('test.dat')
